# %%
import torch 

ckpt = torch.load('/home/ljh/CSC/Enhanced_Syllable_Feature/outputs/finetune/prefix/lr5e-5bs32_epoch10/checkpoint/epoch=9-df=80.0000-cf=78.0357.ckpt')
print(ckpt.keys())
print(ckpt['state_dict'].keys())
# Out:
# dict_keys(['epoch', 'global_step', 'pytorch-lightning_version', 'state_dict', 'callbacks', 'optimizer_states', 'lr_schedulers', 'hparams_name', 'hyper_parameters'])
# ...

# %%
import torch 

ckpt = torch.load('/home/ljh/CSC/Enhanced_Syllable_Feature/outputs/finetune/prefix/prefixlen100_epoch5_oringin/checkpoint/prefixlen=0mid_dim=0epoch=0-df=59.6457-cf=51.1811.ckpt')
print(ckpt.keys())
print(ckpt['state_dict']['model.wte.weight'])
ckpt2 = torch.load('/home/ljh/CSC/Enhanced_Syllable_Feature/outputs/finetune/prefix/prefixlen100_epoch5_oringin/checkpoint/prefixlen=0mid_dim=0epoch=1-df=59.6457-cf=51.1811.ckpt')
for key in ckpt['state_dict'].keys():
    print(ckpt['state_dict'][key] == ckpt2['state_dict'][key])
# Out:
# dict_keys(['epoch', 'global_step', 'pytorch-lightning_version', 'state_dict', 'callbacks', 'optimizer_states', 'lr_schedulers', 'hparams_name', 'hyper_parameters'])
# tensor([[-0.2753, -0.3048, -0.9881,  ..., -0.9853, -0.2245,  0.2291],
#         [ 0.7247, -1.2556,  1.2451,  ..., -2.0650, -0.7351,  1.3237],
#         [ 0.7014,  0.8221,  0.7550,  ..., -1.0727,  2.2377, -0.5310],
#         ...,
#         [-0.9856,  0.9729,  0.1893,  ...,  1.0305, -0.4694,  1.7612],
#         [ 1.2314,  0.0892, -1.4393,  ...,  1.9005, -2.1755,  1.7998],
#         [ 1.9065, -1.9421,  0.6913,  ...,  1.3626, -1.5369, -0.0845]],
#        device='cuda:0')
# tensor([[True, True, True, True, True, True, True, True, True, True, True, True,
#          True, True, True, True, True, True, True, True, True, True, True, True,
#          True, True, True, True, True, True, True, True, True, True, True, True,
#          True, True, True, True, True, True, True, True, True, True, True, True,
# ...
